# %%
import sys
import numpy as np
import glob
import os

import matplotlib.pyplot as plt
import random
if ('/ProgramStudy/Unreal/AD_Cookbook_AirSim/AutonomousDronCookbook/AirSimE2EDeepLearning' not in sys.path):
    sys.path.insert(0, '/ProgramStudy/Unreal/AD_Cookbook_AirSim/AutonomousDronCookbook/AirSimE2EDeepLearning')
from AirSimClient import *
print(random.randint(-15,15))
# Out:
# -7

# %%
def get_image():
    image_response = client.simGetImages([ImageRequest(0, AirSimImageType.Scene, False, False)])[0]
    image1d = np.fromstring(image_response.image_data_uint8, dtype=np.uint8)
    image_rgba = image1d.reshape(image_response.height, image_response.width, 4)
    
    return image_rgba[76:135,0:255,0:3].astype(float)

# %%
client = MultirotorClient()
client.confirmConnection()
client.enableApiControl(True)
client.armDisarm(True)
print('Connection established!')
#state = client.getMultirotorState()
#imu_data = client.getImuData()
#barometer_data = client.getBarometerData()
#magnetometer_data = client.getMagnetometerData()
#gps_data = client.getGpsData()
# Out:
# Waiting for connection:
# Connection established!

# %%
print('start')
image_buf = np.zeros((1, 59, 255, 3))
state_buf = np.zeros((1,4))
#airsim.wait_key('Press an key to takeoff')
client.takeoff()
client.isApiControlEnabled()
while (True):
    print(1)
    #client.moveByRollPitchYawThrottleAsync(3.141592/6, 0, 0, 1, duration = 0.5).join()  #roll, pitch, yaw, throttle, duration / angle -> radians, throttle -> 0~1
    client.moveToZ(1, 50)
    #client.hoverAsync().join()

    state = client.getPosition()
    #if (car_state.speed < 5):
        #car_controls.throttle = 1.0
    #else:
        #car_controls.throttle = 0.0
    
    image = get_image()
    plt.imshow(image)
    plt.show()
    #image_buf[0] = get_image()
    #state_buf[0] = np.array([car_controls.steering, car_controls.throttle, car_controls.brake, car_state.speed])
    #model_output = model.predict([image_buf, state_buf])
# Out:
# start
# 1
# C:\Users\roybatty0601\Anaconda3\envs\pytorch\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1
# 1
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...
