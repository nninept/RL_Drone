# %%
from DroneEnv import DroneAutomaticDrivingEnv
import math
import collections
import random
import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np

# %%
class DronNet(nn.Module):
    def __init__(self):
        super(DronNet, self).__init__()
        self.valueNetwork = nn.Sequential(
            nn.Linear(22, 256),
            nn.ReLU(),
            nn.Linear(256, 256),
            nn.ReLU(),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Linear(128,64),
            nn.ReLU()
        )
        self.x_y = nn.Linear(66,5)
        self.w = Variable(torch.FloatTensor())
        self.epsilon = 0.02
        self.gamma = 0.9
        self.step_size = 0.1
        
    def forward(self, x):
        output = self.valueNetwork(x[0:22])
        new_input = torch.cat([torch.unsqueeze(output,1), torch.unsqueeze(x[22:],1)]).view(-1)
        x_y_output = self.x_y(new_input)
        return x_y_output
    
    def sample_action(self, state):
        pi = self.forward(torch.from_numpy(state).float())
        if random.random() < self.epsilon:
            action = np.random.randint(0,5)
            return action, max(pi)
        else : 
            action = torch.argmax(pi).item()
            return action, max(pi)

# %%
def main():
    env = DroneAutomaticDrivingEnv()
    model = DronNet()
    

    score_pre = 0
    optimizer = optim.Adam(model.parameters(), lr=0.005)
    for episode in range(1000):
        last_state = env.reset()
        score = 0.0  
        while True:
            last_action, pre_value = model.sample_action(last_state)
            optimizer.zero_grad()
            pre_value.backward()
            
            state, r, done, info = env.step(last_action)
            action, value = model.sample_action(state)
            delta = (r + model.gamma * value - pre_value)
            
            for i in range(4):
                model.valueNetwork[i*2].weight.grad = -delta*model.valueNetwork[i*2].weight.grad
            model.x_y.weight.grad = -delta*model.x_y.weight.grad
            optimizer.step()

            last_state = state
            last_action = action
            pre_value = value
            score += r
            if done:
                break
            env.render()

        env.close()
        
                    
        score_pre= score
        print(score)

# %%
main()
# Out:
# -176744.05456080212
# -122094.61372165772
# -189508.24524995527
# -55948.31070040812
# -2512.4629712164847
# -22577.25794556573
# -2032.5547456618576
# -14566.404768161117
# 536.9045058984827
# -1449.3425628545288
# -661.5277639325394
# -469.3993887352094
# -189.0385987384102
# -818.1891891770352
# 300.0
# -1558.2521156656653
# -781.5755320542727
# 526.3981499005532
# 204.58158457573825
# 65.17343245142024
# -718.090963618647
# -616.4256213743706
# -825.9348601968629
# 300.0
# -1041.2591962051767
# -1108.3709900576152
# -539.8632218457576
# -1103.2211376142495
# 95.84052751085264
# -844.6282457982808
# -1573.7924199454985
# -7241.398338259473
# -1334.5143580877875
# -1171.702185684131
# -1352.775209309113
# -533.099058459895
# -792.8151496791218
# -1497.0910703755126
# 300.0
# 300.0
# 132.6841793622552
# -715.6012295318291
# -717.5199885068489
# -597.8286986552517
# 300.0
# -4.601060205714873
# -819.512825463218
# -25.158324252968782
# -599.7465259308073
# -507.1886862486497
# 18.67771301377337
# -826.2461635079728
# -507.16068161351643
# 571.8454757435436
# -618.6283490471249
# 128.63438041786455
# -896.3321368295562
# -867.4433198748179
# 300.0
# -713.5810384331246
# -1388.1685036226331
# -957.8089743114166
# -428.668421058703
# -321.16140125295453
# -905.5908082357125
# 523.2379611309316
# -1004.937732160857
# 300.0
# 475.31904366360834
# -820.3003934807294
# 586.6576724329309
# -1491.2008390070987
# 300.0
# -850.3153955029927
# -1499.0282868761465
# -444.7220407408878
# -437.99997196443434
# -160.24734720954112
# -781.9881166045878
# 595.157932693616
# -768.0863446601104
# 300.0
# -989.9646116875242
# -1034.2551324569606
# -1123.7221452108333
# -1094.824661726013
# -764.0749765066627
# -735.0065306015147
# 300.0
# -862.6395245741112
# -1455.4400094673608
# 5.580247877116324
# -1228.164230249505
# -218.6975266338834
# 300.0
# -745.0286854740416
# -844.9799571254852
# -1498.1595149322272
# 300.0
# -673.9291863237642
# -689.0090101316232
# -791.9887856399916
# -1100.707578671029
# -794.526528746958
# -749.2011994090126
# -698.3887362724863
# 31.8861944224089
# -786.8993282707386
# -1000.2817867245901
# -917.3386272759138
# -107.11912089672751
# -360.5194752787597
# -987.26031781842
# -266.606965268462
# -1186.2924135823373
# -814.5447888726384
# -281.1279956136352
# -1083.5586068756832
# -1307.393596254242
# 239.18139460251373
# 147.09632848532084
# 638.472227878807
# 300.0
# -1336.7322603849204
# -183.58671174438143
# -542.1311077283208
# -696.4375899471275
# -605.2326962710334
# -732.8440249167934
# -764.9292899914707
# -698.4782296735066
# 368.61624116828966
# -368.3381182031268
# -916.4925716404346
# 300.0
# -1275.1252329850943
# -1146.3940474008907
# -986.3283268814736
# -754.5842287782191
# 555.0830599285601
# 33.01676521126488
# -743.826576925345
# -927.242032378965
# -1240.412515718085
# -1108.0855401078256
# -624.264718115765
# -1086.0927988297942
# -834.6335276057708
# -837.1757598834943
# -955.5587224155107
# -1340.113394244783
# 603.837860520753
# -982.5579220171052
# -868.9071585709573
# -460.05748876516043
# 300.0
# -970.152991746629
# 82.10870536063857
# -916.1845885026328
# -1211.369296107662
# -436.43456531701827
# -404.6471622238812
# -63.74263972480243
# -1365.9932407496326
# -834.8843058263476
# -563.3015045788616
# -697.715945598632
# 262.51353116583897
# -1192.0865830316295
# -976.9633091760554
# -732.2431039634115
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-263240bbee7e> in <module>
# ----> 1 main()
#
# <ipython-input-3-77684987b6d4> in main()
#      29             if done:
#      30                 break
# ---> 31             env.render()
#      32
#      33         env.close()
#
# C:\ProgramStudy\PyStudy\학회\Dron\DroneEnv.py in render(self, mode)
#     305         if self.viewer is None:
#     306             from gym.envs.classic_control import rendering
# --> 307             self.viewer = rendering.Viewer(screen_width, screen_height)
#     308             l,r,t,b = -drone_width/2, drone_width/2, drone_height/2, -drone_height/2
#     309
#
# ~\Anaconda3\lib\site-packages\gym\envs\classic_control\rendering.py in __init__(self, width, height, display)
#      58         self.width = width
#      59         self.height = height
# ---> 60         self.window = pyglet.window.Window(width=width, height=height, display=display)
#      61         self.window.on_close = self.window_closed_by_user
#      62         self.isopen = True
#
# ~\Anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in __init__(self, *args, **kwargs)
#     132
#     133
# --> 134         super(Win32Window, self).__init__(*args, **kwargs)
#     135
#     136     def _recreate(self, changes):
#
# ~\Anaconda3\lib\site-packages\pyglet\window\__init__.py in __init__(self, width, height, caption, resizable, style, fullscreen, visible, vsync, display, screen, config, context, mode)
#     569         from pyglet import app
#     570         app.windows.add(self)
# --> 571         self._create()
#     572
#     573         self.switch_to()
#
# ~\Anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in _create(self)
#     269         self.set_caption(self._caption)
#     270
# --> 271         self.switch_to()
#     272         self.set_vsync(self._vsync)
#     273
#
# ~\Anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in switch_to(self)
#     315
#     316     def switch_to(self):
# --> 317         self.context.set_current()
#     318
#     319     def flip(self):
#
# ~\Anaconda3\lib\site-packages\pyglet\gl\win32.py in set_current(self)
#     215         if self._context is not None:
#     216             wgl.wglMakeCurrent(self.canvas.hdc, self._context)
# --> 217         super(Win32Context, self).set_current()
#     218
#     219     def detach(self):
#
# ~\Anaconda3\lib\site-packages\pyglet\gl\base.py in set_current(self)
#     305         if not self._info:
#     306             self._info = gl_info.GLInfo()
# --> 307             self._info.set_active_context()
#     308             for attr, check in self._workaround_checks:
#     309                 setattr(self, attr, check(self._info))
#
# ~\Anaconda3\lib\site-packages\pyglet\gl\gl_info.py in set_active_context(self)
#     106                          c_char_p).value).split()
#     107             if self.extensions:
# --> 108                 self.extensions = set(self.extensions)
#     109             self._have_info = True
#     110
#
# ~\Anaconda3\lib\site-packages\pyglet\gl\gl_info.py in <genexpr>(.0)
#     101                 glGetIntegerv(GL_NUM_EXTENSIONS, num_extensions)
#     102                 self.extensions = (asstr(cast(glGetStringi(GL_EXTENSIONS, i),
# --> 103                                          c_char_p).value) for i in range(num_extensions.value))
#     104             else:
#     105                 self.extensions = asstr(cast(glGetString(GL_EXTENSIONS),
#
# ~\Anaconda3\lib\site-packages\pyglet\gl\lib.py in errcheck(result, func, arguments)
#     100         raise GLException('No GL context; create a Window first')
#     101     if not context._gl_begin:
# --> 102         error = gl.glGetError()
#     103         if error:
#     104             msg = ctypes.cast(gl.gluErrorString(error), ctypes.c_char_p).value
#
# KeyboardInterrupt:
